# %% [markdown]
# ## 4. Modellauswahl

# %%
import pandas as pd

X = pd.read_csv('../model/feature_matrix.csv')
y = pd.read_csv('../model/target_variable.csv')

# %%
X
# Out:
#        Marke  Modell  Baujahr  Getriebe  Kilometerstand  Kraftstoffart  \
# 0          0       9     2017         2           25322              1
# 1          0      14     2016         0           58262              2
# 2          0       9     2016         2           48193              1
# 3          0      12     2017         0           41765              2
# 4          0      11     2019         2            3215              1
# ...      ...     ...      ...       ...             ...            ...
# 97704      8      57     2012         2          119091              2
# 97705      8      62     2008         2          141786              1
# 97706      8      62     2009         2          112653              1
# 97707      8      62     2006         2          133098              1
# 97708      8      62     2007         2          119091              1
#
#        Verbrauch (l/100km)  Motorgröße (l)  Steuer (€)  Alter
# ...

# %%
y
# Out:
#        Preis (€)
# 0       14375.00
# 1       18975.00
# 2       12650.00
# 3       19320.00
# 4       19895.00
# ...          ...
# 97704    6888.50
# 97705    2068.85
# 97706    1828.50
# 97707    1437.50
# 97708    2639.25
#
# [97709 rows x 1 columns]
